# %% [markdown]
# # SUMMER ANALYTICS 2024

# %% [markdown]
# # Week-1 Assignment

# %% [markdown]
# ![493179.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Grand Prix!**

# %% [markdown]
# **Welcome to your first assignment of Summer Analytics 2025! We hope you are excited to implement and test everything you have learnt up until now. The dataset which you'll use includes information about cars.**
#
# **We've got an interesting set of questions for you to get a basic understanding of pandas and data visualization libraries. GOOD LUCK!**
#
#
# ***Let's get started with importing numpy, pandas, seaborn and matplotlib!***
#
# Note - matplotlib should be imported with the command :
#
#  `import matplotlib.pyplot as plt`

# %% [markdown]
# ![image.avif](data:image/avif;base64,...)

# %% [markdown]
# **So lets get started!! Buckle up your belts for this exciting ride!!**

# %% [markdown]
# ### 1) Start by importing all important libraries
# For eg, "import numpy as np"

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 2) Read the csv file and assign it to a variable .

# %%
df = pd.read_csv('cars.csv')
print(df.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# ### 3) Display shape of dataframe
# Expected Output - (398, 9)

# %%
print(df.shape)
# Out:
# (398, 9)

# %% [markdown]
# ### 4) Print all columns of dataframe
# Return an array containing names of all the columns.

# %%
column_name = df.columns.tolist()
print(column_name)
# Out:
# ['mpg', 'cylinders', 'displacement', 'horsepower', 'weight', 'acceleration', 'model_year', 'origin', 'name']

# %% [markdown]
# ### 6) Set the 'name' column as the index of dataframe

# %%
df.set_index('name', inplace=True)

# %% [markdown]
# ###  7) Print a list of all the unique mpg values

# %%
import pandas as pd
df = pd.read_csv('Cars.csv')
Unique_mpg = sorted(df['mpg'].astype(float))
print(Unique_mpg)
# Out:
# [9.0, 10.0, 10.0, 11.0, 11.0, 11.0, 11.0, 12.0, 12.0, 12.0, 12.0, 12.0, 12.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 13.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.0, 14.5, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.0, 15.5, 15.5, 15.5, 15.5, 15.5, 16.0, 16.0, 16.0, 16.0, 16.0, 16.0, 16.0, 16.0, 16.0, 16.0, 16.0, 16.0, 16.0, 16.2, 16.5, 16.5, 16.5, 16.9, 17.0, 17.0, 17.0, 17.0, 17.0, 17.0, 17.0, 17.5, 17.5, 17.5, 17.5, 17.5, 17.6, 17.6, 17.7, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.0, 18.1, 18.1, 18.2, 18.5, 18.5, 18.5, 18.6, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.0, 19.1, 19.2, 19.2, 19.2, 19.4, 19.4, 19.8, 19.9, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.0, 20.2, 20.2, 20.2, 20.2, 20.3, 20.5, 20.5, 20.5, 20.6, 20.6, 20.8, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.0, 21.1, 21.5, 21.5, 21.5, 21.6, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.0, 22.3, 22.4, 22.5, 23.0, 23.0, 23.0, 23.0, 23.0, 23.0, 23.0, 23.0, 23.0, 23.0, 23.2, 23.5, 23.6, 23.7, 23.8, 23.9, 23.9, 24.0, 24.0, 24.0, 24.0, 24.0, 24.0, 24.0, 24.0, 24.0, 24.0, 24.0, 24.2, 24.3, 24.5, 24.5, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.0, 25.1, 25.4, 25.4, 25.5, 25.5, 25.8, 26.0, 26.0, 26.0, 26.0, 26.0, 26.0, 26.0, 26.0, 26.0, 26.0, 26.0, 26.0, 26.0, 26.0, 26.4, 26.5, 26.6, 26.6, 26.8, 27.0, 27.0, 27.0, 27.0, 27.0, 27.0, 27.0, 27.0, 27.0, 27.2, 27.2, 27.2, 27.4, 27.5, 27.9, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.0, 28.1, 28.4, 28.8, 29.0, 29.0, 29.0, 29.0, 29.0, 29.0, 29.0, 29.0, 29.5, 29.5, 29.8, 29.8, 29.9, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.0, 30.5, 30.5, 30.7, 30.9, 31.0, 31.0, 31.0, 31.0, 31.0, 31.0, 31.0, 31.3, 31.5, 31.5, 31.6, 31.8, 31.9, 32.0, 32.0, 32.0, 32.0, 32.0, 32.0, 32.1, 32.2, 32.3, 32.4, 32.4, 32.7, 32.8, 32.9, 33.0, 33.0, 33.0, 33.5, 33.5, 33.5, 33.7, 33.8, 34.0, 34.0, 34.1, 34.1, 34.2, 34.3, 34.4, 34.5, 34.5, 34.7, 35.0, 35.0, 35.1, 35.7, 36.0, 36.0, 36.0, 36.0, 36.0, 36.0, 36.1, 36.1, 36.4, 37.0, 37.0, 37.0, 37.2, 37.3, 37.7, 38.0, 38.0, 38.0, 38.0, 38.1, 39.0, 39.1, 39.4, 40.8, 40.9, 41.5, 43.1, 43.4, 44.0, 44.3, 44.6, 46.6]

# %% [markdown]
# ### 8) Create a column which contains the horsepower divided by weightas its metric and make this new column the index.

# %%
df['horsepower'] = pd.to_numeric(df['horsepower'], errors= 'coerce')
df['weight'] = pd.to_numeric(df['weight'], errors='coerce')
df['hp_per_weight'] = df['horsepower']/df['weight']
df.set_index('hp_per_weight')
print(df.head())
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  hp_per_weight
# 0          70    usa  chevrolet chevelle malibu       0.037100
# 1          70    usa          buick skylark 320       0.044679
# 2          70    usa         plymouth satellite       0.043655
# 3          70    usa              amc rebel sst       0.043694
# 4          70    usa                ford torino       0.040591

# %% [markdown]
# ![OIP (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Checkpoint!!
# Congratulations on making it this far. You are really keeping up in Data Grand Prix.
# Now starts the real race i.e. graded questions of the quiz.**

# %% [markdown]
# ## GRADED Questions (To be answered in the quiz)
# ### Try to retrieve some information from the data and answer the questions below . BEST OF LUCK !!

# %% [markdown]
# ### 1. What is name of car that has the highest horsepower?

# %%
max_hp_row = df[df['horsepower'] == df['horsepower'].max()]


car_name = max_hp_row['name'].values[0]
print("Car with the highest horsepower:", car_name)
# Out:
# Car with the highest horsepower: pontiac grand prix

# %% [markdown]
# ### 2. How many cars have mpg ≥ 35?

# %%
high_mpg_count = df[df['mpg'] >= 35].shape[0]
print("number of cars with mpg >= 35:", high_mpg_count)
# Out:
# number of cars with mpg >= 35: 36

# %% [markdown]
# ### 3. What is the most common origin for cars with horsepower > 100 and weight < 3000?

# %%
filtered = df[(df['horsepower'] > 100) & (df['weight'] > 3000)]
most_common_origin = filtered['origin'].value_counts().idxmax()

print("most common origin:", most_common_origin)
# Out:
# most common origin: usa

# %% [markdown]
# ### 4. What is the mean acceleration of cars from Japan? (rounded to 2 decimals)

# %%
mean_acc_japan = round(df[df['origin'] == 'japan']['acceleration'].mean(), 2)
print("mean acceleration of cars from japan:", mean_acc_japan)
# Out:
# mean acceleration of cars from japan: 16.17

# %% [markdown]
# ### 5. Which year had the highest average mpg?

# %%
avg_mpg_per_year = df.groupby('model_year')['mpg'].mean()
highest_avg_year = avg_mpg_per_year.idxmax()

print("year with highest average mpg:", highest_avg_year)
# Out:
# year with highest average mpg: 80

# %% [markdown]
# ## *Congratulations on coming this far! Since we were having so much fun playing with this dataset, let's move towards finish line by attempting some Ungraded questions!*
#
# ### **Note:** These questions are UNGRADED, and are given as an extra exercise.

# %% [markdown]
# ### Find the car (or cars) with the best ratio of horsepower to weight among all cars that also have above-median mpg.

# %%
import pandas as pd

df = pd.read_csv("cars.csv")  
df = df.dropna(subset=['horsepower', 'weight', 'mpg'])

median_mpg = df['mpg'].median()
df_above_median = df[df['mpg'] > median_mpg].copy()  

df_above_median['hp_to_weight'] = df_above_median['horsepower'] / df_above_median['weight']

best_ratio = df_above_median['hp_to_weight'].max()
best_cars = df_above_median[df_above_median['hp_to_weight'] == best_ratio]

print("Car(s) with best HP-to-weight ratio and above-median mpg:")
print(best_cars)
# Out:
# Car(s) with best HP-to-weight ratio and above-median mpg:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 23  26.0          4         121.0       113.0    2234          12.5
#
#     model_year  origin      name  hp_to_weight
# 23          70  europe  bmw 2002      0.050582

# %% [markdown]
# ### Design a multi-line plot using Matplotlib or Seaborn that shows the evolution of average mpg over the years, separately for each origin

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


df = pd.read_csv('cars.csv') 

avg_mpg = df.groupby(['model_year', 'origin'])['mpg'].mean().reset_index()
plt.figure(figsize=(12, 6))
sns.lineplot(data=avg_mpg, x='model_year', y='mpg', hue='origin', marker='o')

plt.title('Evolution of Average MPG Over the Years by Origin')
plt.xlabel('Model Year')
plt.ylabel('Average MPG')
plt.legend(title='Origin')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Create a Seaborn scatterplot (or PairGrid) where:
#
# X = horsepower
#
# Y = weight
#
# Color by: origin
#
# Size by: mpg
#
# Hue order = ['japan', 'europe', 'usa']
#
# Add meaningful plot titles and axis titles.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x='horsepower',
    y='weight',
    hue='origin',
    size='mpg',
    hue_order=['japan', 'europe', 'usa'],
    sizes=(40, 200), 
    palette='Set2',  
    alpha=0.7
)

plt.title("Car Horsepower vs Weight by Origin", fontsize=16)
plt.xlabel("Horsepower", fontsize=12)
plt.ylabel("Weight", fontsize=12)
plt.legend(title='Origin', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### We define a “consistent” car model as one that was produced over multiple years and had very low variation in mpg across those years (standard deviation < 1.0).
#
# Tasks:
#
# Identify car names that appear in more than one model_year.
#
# For each such name, compute the standard deviation of mpg across years.
#
# Return the car(s) with the lowest variation in mpg, among those with at least 2 appearances and std(mpg) < 1.0.
#
# Report the model name(s), number of appearances, and the average mpg.
#
# Bonus:
# Sort the result by number of appearances (descending), then mpg (descending).

# %%
import pandas as pd


grouped = df.groupby('name')
multi_year = grouped.filter(lambda x: x['model_year'].nunique() > 1)
summary = multi_year.groupby('name').agg(
    count=('mpg', 'count'),
    std_mpg=('mpg', 'std'),
    avg_mpg=('mpg', 'mean')
).reset_index()

consistent = summary[(summary['count'] >= 2) & (summary['std_mpg'] < 1.0)]

consistent_sorted = consistent.sort_values(by=['count', 'avg_mpg'], ascending=[False, False])


consistent_sorted
# Out:
#                          name  count   std_mpg    avg_mpg
# 26           ford galaxie 500      3  0.577350  14.333333
# 41          plymouth fury iii      3  0.577350  14.333333
# 49        toyota corolla 1200      2  0.707107  31.500000
# 35                  mazda 626      2  0.212132  31.450000
# 53          volkswagen rabbit      2  0.353553  29.250000
# 21               datsun pl510      2  0.000000  27.000000
# 45                  saab 99le      2  0.707107  24.500000
# 51             toyota mark ii      2  0.707107  19.500000
# 22                dodge aspen      2  0.353553  18.850000
# 10  chevrolet chevelle malibu      2  0.707107  17.500000
# 4            amc matador (sw)      2  0.707107  14.500000
# 28      ford gran torino (sw)      2  0.707107  13.500000
# 29                   ford ltd      2  0.707107  13.500000

# %% [markdown]
# ![OIP.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Congratulations on completing the race. Kudos to you. Looking forward to meet you in next week.**
